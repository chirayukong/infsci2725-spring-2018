# %% [markdown]
# # Statistics
#
# 1. Describing and displaying data
#     1. Describing data
#     1. Measures of central tendency
#         1. mode
#         1. median
#         1. mean
#         1. trimmed mean
#     1. Measures of spread
#         1. range
#         1. variance
#         1. standard deviation
#         1. average absolute deviation (or mean absolute deviation)
# 1. Probability Distribution + generating data from randomness
#     1. Normal Distribution
#     1. Log-Normal Distribution
#     1. Uniform Distribution
#     1. Beta Distribution
#     1. Exponential Distribution
#     1. Triangular Distribution
#     1. Binomial Distribution
#     1. Weibull Distribution
# 1. Scatter plots
# 1. Correlation
# 1. Linear regression
# 1. Time series
# 1. Outliers

# %%
import matplotlib.pyplot as plt # https://matplotlib.org/api/pyplot_summary.html
import numpy as np # https://docs.scipy.org/doc/numpy/reference/
import pandas as pd # https://pandas.pydata.org/pandas-docs/stable/
import scipy.special as spec # https://docs.scipy.org/doc/scipy/reference/special.html
import scipy.stats as st # https://docs.scipy.org/doc/scipy/reference/stats.html
import seaborn as sns # https://seaborn.pydata.org/api.html
# %matplotlib inline

# %% [markdown]
# # Describing and displaying data

# %%
print('Load assignment-01/Batting.csv into Pandas DataFrame')
battings = pd.read_csv('https://raw.githubusercontent.com/chirayukong/infsci2725-spring-2018/master/assignment-01/Batting.csv')
battings.head()
# Out:
# Load assignment-01/Batting.csv into Pandas DataFrame
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>playerID</th>
#       <th>yearID</th>
#       <th>teamID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>kigerma01</td>
#       <td>2006</td>
#       <td>OAK</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
# ...

# %% [markdown]
# ## Describing data

# %%
print('describe')
battings.describe(include='all')
# Out:
# describe
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>playerID</th>
#       <th>yearID</th>
#       <th>teamID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>96183</td>
#       <td>96183.000000</td>
#       <td>96183</td>
#       <td>96183.000000</td>
#       <td>96183.000000</td>
#       <td>96183.000000</td>
#       <td>96183.000000</td>
#       <td>96183.000000</td>
#       <td>96183.000000</td>
# ...

# %% [markdown]
# ## Measures of central tendency

# %%
print('mode')
battings.mode()
# Out:
# mode
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>playerID</th>
#       <th>yearID</th>
#       <th>teamID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>mcguide01</td>
#       <td>2015</td>
#       <td>CHN</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
print('median')
battings.median()
# Out:
# median
# yearID          1969.0
# Games             36.0
# Atbats            57.0
# RunsScored         5.0
# Hits              11.0
# Homeruns           0.0
# RunsBattedIn       4.0
# Walks              3.0
# strikeOuts         8.0
# dtype: float64

# %%
print('mean')
battings.mean()
# Out:
# mean
# yearID          1962.271888
# Games             52.999823
# Atbats           149.970327
# RunsScored        19.887038
# Hits              39.261647
# Homeruns           2.949305
# RunsBattedIn      17.885967
# Walks             13.811484
# strikeOuts        19.867222
# dtype: float64

# %%
print('trimmed mean')
grouped_df = battings.groupby(['yearID'])
grouped_df['Atbats'].apply(st.trim_mean, proportiontocut=0.1).tail()
# Out:
# trimmed mean
# yearID
# 2011    82.452830
# 2012    79.246454
# 2013    80.147919
# 2014    77.006963
# 2015    72.505882
# Name: Atbats, dtype: float64

# %% [markdown]
# ## Measures of spread

# %%
print('range')
battings.describe().loc[['min', 'max']]
# Out:
# range
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>yearID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>min</th>
#       <td>1871.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>2015.0</td>
#       <td>165.0</td>
#       <td>716.0</td>
# ...

# %%
print('variance')
battings.var()
# Out:
# variance
# yearID           1539.234439
# Games            2276.878137
# Atbats          34803.541154
# RunsScored        822.047199
# Hits             2842.056387
# Homeruns           41.083766
# RunsBattedIn      714.171605
# Walks             444.905136
# strikeOuts        777.572719
# dtype: float64

# %%
print('standard deviation')
battings.std()
# Out:
# standard deviation
# yearID           39.233078
# Games            47.716644
# Atbats          186.557072
# RunsScored       28.671365
# Hits             53.310941
# Homeruns          6.409662
# RunsBattedIn     26.723989
# Walks            21.092775
# strikeOuts       27.884991
# dtype: float64

# %%
print('average absolute deviation (or mean absolute deviation)')
battings.mad()
# Out:
# average absolute deviation (or mean absolute deviation)
# yearID           33.650820
# Games            40.194868
# Atbats          154.558953
# RunsScored       22.350103
# Hits             43.170392
# Homeruns          3.985975
# RunsBattedIn     20.368137
# Walks            15.712845
# strikeOuts       20.429150
# dtype: float64

# %% [markdown]
# # Probability Distribution + generating data from randomness

# %%
## Normal Distribution
mu, sigma = 0, 0.1 # mean and standard deviation
normal_data = np.random.normal(mu, sigma, 1000)
count, bins, ignored = plt.hist(normal_data, 30, normed=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
         np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
range_normal = np.linspace(min(bins), max(bins), 100)
plt.plot(range_normal, st.norm.pdf(range_normal, mu, sigma), linewidth=2, color='b')
plt.suptitle('Normal Distribution')
plt.show()

# %%
count, bins, ignored =  plt.hist(np.random.lognormal(mu, sigma, 1000), 30, normed=True)
range_lognormal = np.linspace(min(bins), max(bins), 10000)
pdf = (np.exp(-(np.log(range_lognormal) - mu) ** 2 / (2 * sigma ** 2)) / (range_lognormal * sigma * np.sqrt(2 * np.pi)))
plt.plot(range_lognormal, pdf, linewidth=2, color='b')
plt.suptitle('Log-Normal Distribution')
plt.show()

# %%
# uniform 
lo, hi = 0, 100
uniform_data = np.random.uniform(low=lo, high=hi, size=1000)
count, bins, ignored = plt.hist(uniform_data, 30, normed=True)
plt.plot(bins,  bins/bins / (hi - lo), linewidth=2, color='r')
plt.suptitle('Uniform Distribution')
plt.show()

# %%
a, b = 0.5, 0.5
plt.hist(np.random.beta(a, b, 1000), 30, normed=True)
range_beta = np.linspace(0, 1, 100)
plt.plot(range_beta, st.beta.pdf(range_beta, a, b), linewidth=2, color='b')
plt.suptitle('Beta Distribution')
plt.show()

# %%
ld = 0.5
exponential_data = np.random.exponential(ld, 1000)
count, bins, ignored = plt.hist(exponential_data, 100, normed=True)
range_exponential = np.linspace(0, max(bins), 100)
plt.plot(range_exponential, st.expon.pdf(range_exponential, 0, ld), color='b')
plt.suptitle('Exponential Distribution')
plt.show()

# %%
plt.hist(np.random.triangular(0, 10, 50, 1000), 30, normed=True)
plt.suptitle('Triangular Distribution')
plt.show()

# %%
n = 30
p = 0.5
binomial_data = np.random.binomial(n, p, 1000)
count, bins, ignored = plt.hist(binomial_data, 16, normed=True)
plt.plot(bins, spec.comb(n, bins) * p**bins * (1-p)**(n - bins), linewidth=2, color='r')
range_binomal = np.linspace(min(bins), max(bins), 100)
plt.plot(range_binomal, st.binom._pmf(range_binomal, n, p), color='b')
plt.suptitle('Binomial Distribution')
plt.show()

# %%
plt.hist(np.random.weibull(1,1000), 30, normed=True)
plt.suptitle('Weibull Distribution')
plt.show()

# %% [markdown]
# # Scatter plots

# %%
print('original data')
battings.head()
# Out:
# original data
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>playerID</th>
#       <th>yearID</th>
#       <th>teamID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>kigerma01</td>
#       <td>2006</td>
#       <td>OAK</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %%
print('Data of each player in 2001')
battings_in_2001 = battings.loc[battings['yearID'] == 2001].groupby('playerID').aggregate(np.sum)
battings_in_2001.head()
# Out:
# Data of each player in 2001
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>yearID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#     <tr>
#       <th>playerID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>abadan01</th>
#       <td>2001</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
# ...

# %%
battings_in_2001.plot(kind='scatter', x='Hits', y='Homeruns', title='Scatter plots of Hits VS Homeruns for each player in 2001')

# %% [markdown]
# # Correlation

# %%
print('Correlation matrix using pearson method')
battings.corr(method='pearson')
# Out:
# Correlation matrix using pearson method
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>yearID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>yearID</th>
#       <td>1.000000</td>
#       <td>0.040921</td>
#       <td>-0.073102</td>
#       <td>-0.087965</td>
#       <td>-0.071422</td>
#       <td>0.163027</td>
#       <td>-0.034210</td>
#       <td>-0.009640</td>
#       <td>0.229160</td>
#     </tr>
#     <tr>
#       <th>Games</th>
# ...

# %% [markdown]
# # Linear regression

# %%
print('original data')
battings.head()
# Out:
# original data
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>playerID</th>
#       <th>yearID</th>
#       <th>teamID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>kigerma01</td>
#       <td>2006</td>
#       <td>OAK</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %%
sns.regplot(x='Hits', y='Homeruns', data=battings_in_2001)
_ = plt.title('Linear regression of Hits VS Homeruns for each player in 2001')

# %% [markdown]
# # Time series

# %%
print('original data')
battings.head()
# Out:
# original data
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>playerID</th>
#       <th>yearID</th>
#       <th>teamID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>kigerma01</td>
#       <td>2006</td>
#       <td>OAK</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %%
print('OAK team aggregating columns by year')
oak_by_year = battings.loc[battings['teamID'] == 'OAK'].groupby('yearID').aggregate(np.sum)
oak_by_year.head()
# Out:
# OAK team aggregating columns by year
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#     <tr>
#       <th>yearID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1968</th>
#       <td>2089</td>
#       <td>5406</td>
#       <td>569</td>
#       <td>1300</td>
#       <td>94</td>
#       <td>522</td>
# ...

# %%
oak_by_year.plot()
_ = plt.title('OAK team Time series')

# %% [markdown]
# # Outliers

# %%
print('original data')
battings.head()
# Out:
# original data
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>playerID</th>
#       <th>yearID</th>
#       <th>teamID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>kigerma01</td>
#       <td>2006</td>
#       <td>OAK</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %%
print('Drop non-number columns')
batting_numbers = battings.drop(columns=['playerID', 'teamID'])
batting_numbers.head()
# Out:
# Drop non-number columns
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>yearID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2006</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1886</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
# ...

# %%
print('Describe original data')
battings.describe()
# Out:
# Describe original data
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>yearID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>96183.000000</td>
#       <td>96183.000000</td>
#       <td>96183.000000</td>
#       <td>96183.000000</td>
#       <td>96183.000000</td>
#       <td>96183.000000</td>
#       <td>96183.000000</td>
#       <td>96183.000000</td>
#       <td>96183.000000</td>
#     </tr>
#     <tr>
# ...

# %%
print('Describe data filtered out outliers by | Z-Score | < 3')
cleaned_battings = batting_numbers[(np.abs(st.zscore(batting_numbers)) < 3).all(axis=1)]
cleaned_battings.describe()
# Out:
# Describe data filtered out outliers by | Z-Score | < 3
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>yearID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>90346.000000</td>
#       <td>90346.000000</td>
#       <td>90346.000000</td>
#       <td>90346.000000</td>
#       <td>90346.000000</td>
#       <td>90346.000000</td>
#       <td>90346.000000</td>
#       <td>90346.000000</td>
#       <td>90346.000000</td>
# ...

# %%
print('mode of original data')
batting_numbers.mode()
# Out:
# mode of original data
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>yearID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2015</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
print('mode of cleaned data')
cleaned_battings.mode()
# Out:
# mode of cleaned data
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>yearID</th>
#       <th>Games</th>
#       <th>Atbats</th>
#       <th>RunsScored</th>
#       <th>Hits</th>
#       <th>Homeruns</th>
#       <th>RunsBattedIn</th>
#       <th>Walks</th>
#       <th>strikeOuts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2015</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
print('median of original data')
batting_numbers.median()
# Out:
# median of original data
# yearID          1969.0
# Games             36.0
# Atbats            57.0
# RunsScored         5.0
# Hits              11.0
# Homeruns           0.0
# RunsBattedIn       4.0
# Walks              3.0
# strikeOuts         8.0
# dtype: float64

# %%
print('median of of cleaned data')
cleaned_battings.median()
# Out:
# median of of cleaned data
# yearID          1969.0
# Games             33.0
# Atbats            48.0
# RunsScored         4.0
# Hits               9.0
# Homeruns           0.0
# RunsBattedIn       3.0
# Walks              3.0
# strikeOuts         7.0
# dtype: float64

# %%
battings_in_2001.plot(kind='scatter', x='Hits', y='Homeruns', title='Scatter plots of Hits VS Homeruns for each player in 2001')

# %%
cleaned_battings.loc[battings['yearID'] == 2001].groupby('playerID').aggregate(np.sum).plot(kind='scatter', x='Hits', y='Homeruns', title='Scatter plots of Hits VS Homeruns for each player in 2001')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-02d637e2c569> in <module>()
# ----> 1 cleaned_battings.loc[battings['yearID'] == 2001].groupby('playerID').aggregate(np.sum).plot(kind='scatter', x='Hits', y='Homeruns', title='Scatter plots of Hits VS Homeruns for each player in 2001')
#
# /Users/sahawut/pyenvs/da'18-1/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /Users/sahawut/pyenvs/da'18-1/lib/python3.6/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
# ...
